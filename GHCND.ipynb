# %%
cd ~/github/datasets
# Out:
# /projects/adb33eca-1c24-48f8-bc93-2f1c06dbfcd6/github/datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time as dt
# %matplotlib inline
df = pd.read_csv('598354.csv')

# %% [markdown]
# #format date string

# %%
df['Date2']=pd.to_datetime((df.DATE).apply(str),'%Y%m%d')
df = df[(df.TMIN>-9999)]

# %% [markdown]
# #exploring data

# %%
df.describe()
# Out:
#                   DATE           MDPR           DAPR           PRCP  \
# count    366526.000000  366526.000000  366526.000000  366526.000000
# mean   20144507.008452   -9984.338625   -9984.454964   -4634.029744
# std        4790.578236     384.292663     381.143216    4992.628031
# min    20140101.000000   -9999.000000   -9999.000000   -9999.000000
# 25%    20140530.000000   -9999.000000   -9999.000000   -9999.000000
# 50%    20141027.000000   -9999.000000   -9999.000000       0.000000
# 75%    20150327.000000   -9999.000000   -9999.000000       0.000000
# max    20150902.000000    2543.000000      21.000000   12344.000000
#
#                 TMAX           TMIN           TOBS
# count  366526.000000  366526.000000  366526.000000
# mean      221.896488      92.067029   -6498.226167
# std       294.855250      76.124425    4822.294090
# min     -9999.000000    -994.000000   -9999.000000
# 25%       172.000000      44.000000   -9999.000000
# ...

# %%
df.head(10)
# Out:
#              STATION                   STATION_NAME      DATE  MDPR  DAPR  \
# 0  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140101 -9999 -9999
# 1  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140102 -9999 -9999
# 2  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140103 -9999 -9999
# 3  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140104 -9999 -9999
# 4  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140105 -9999 -9999
# 5  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140106 -9999 -9999
# 6  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140107 -9999 -9999
# 7  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140108 -9999 -9999
# 8  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140109 -9999 -9999
# 9  GHCND:USR0000CTHO  THOMES CREEK CALIFORNIA CA US  20140110 -9999 -9999
#
#    PRCP  TMAX  TMIN  TOBS
# 0 -9999   217    83 -9999
# 1 -9999   217    72 -9999
# 2 -9999   206    78 -9999
# 3 -9999   206    94 -9999
# ...

# %%
grp = df.groupby(['STATION'])
#grp.agg(np.mean)
grp.head()
# Out:
#                   STATION                     STATION_NAME      DATE  MDPR  \
# 0       GHCND:USR0000CTHO    THOMES CREEK CALIFORNIA CA US  20140101 -9999
# 1       GHCND:USR0000CTHO    THOMES CREEK CALIFORNIA CA US  20140102 -9999
# 2       GHCND:USR0000CTHO    THOMES CREEK CALIFORNIA CA US  20140103 -9999
# 3       GHCND:USR0000CTHO    THOMES CREEK CALIFORNIA CA US  20140104 -9999
# 4       GHCND:USR0000CTHO    THOMES CREEK CALIFORNIA CA US  20140105 -9999
# 610     GHCND:USC00049099           TWENTYNINE PALMS CA US  20140101 -9999
# 611     GHCND:USC00049099           TWENTYNINE PALMS CA US  20140102 -9999
# 612     GHCND:USC00049099           TWENTYNINE PALMS CA US  20140103 -9999
# 613     GHCND:USC00049099           TWENTYNINE PALMS CA US  20140104 -9999
# 614     GHCND:USC00049099           TWENTYNINE PALMS CA US  20140105 -9999
# 1200    GHCND:USR0000CRDR    READER RANCH CALIFORNIA CA US  20140101 -9999
# ...

# %%
grp.max().sort('PRCP', ascending =False)
#grp.max().sort('TMIN', ascending =False)
# Out:
#                                        STATION_NAME      DATE  MDPR  DAPR  \
# STATION
# GHCND:USS0019L06S                 POISON FLAT CA US  20150831 -9999 -9999
# GHCND:US1CANV0006          GRASS VALLEY 5.0 S CA US  20140811 -9999 -9999
# GHCND:US1CALK0010                  COBB 0.8 S CA US  20150829 -9999 -9999
# GHCND:USC00045679                     MINERAL CA US  20150828   635     9
# GHCND:US1CASN0098              CAZADERO 5.6 W CA US  20150828 -9999 -9999
# GHCND:USC00041018                  BOWMAN DAM CA US  20150731 -9999 -9999
# GHCND:USC00049273                      VENADO CA US  20150902 -9999 -9999
# GHCND:US1CANV0034         GRASS VALLEY 4.2 SE CA US  20150611 -9999 -9999
# GHCND:US1CAMT0014              BIG SUR 3.2 SE CA US  20150807 -9999 -9999
# GHCND:US1CASN0099         GUERNEVILLE 2.0 SSW CA US  20150710 -9999 -9999
# GHCND:USC00044074               HONEYDEW 1 SW CA US  20150902 -9999 -9999
# ...

# %%
grpA.describe()
# Out:
#                   DATE  MDPR  DAPR        PRCP        TMAX        TMIN  \
# count       592.000000   592   592  592.000000  592.000000  592.000000
# mean   20144416.684122 -9999 -9999    0.731419  334.432432  158.572635
# std        4766.726542     0     0    5.410133   75.341022   77.409703
# min    20140101.000000 -9999 -9999    0.000000  133.000000  -50.000000
# 25%    20140528.750000 -9999 -9999    0.000000  276.500000  100.000000
# 50%    20141023.500000 -9999 -9999    0.000000  336.000000  161.000000
# 75%    20150320.250000 -9999 -9999    0.000000  406.000000  222.000000
# max    20150828.000000 -9999 -9999   79.000000  483.000000  339.000000
#
#               TOBS
# count   592.000000
# mean    222.016892
# std     848.840611
# min   -9999.000000
# 25%     211.000000
# 50%     306.000000
# 75%     378.000000
# max     461.000000

# %% [markdown]
# #selecting the three stations with the most observations

# %%
grp.max().sort('TOBS', ascending =False)
# Out:
#                                           STATION_NAME      DATE  MDPR  DAPR  \
# STATION
# GHCND:USC00045502             MECCA FIRE STATION CA US  20150828 -9999 -9999
# GHCND:USC00046386             OCOTILLO WELLS 2 W CA US  20150901    15     2
# GHCND:USC00040983            BORREGO DESERT PARK CA US  20150902 -9999 -9999
# GHCND:USC00044259             INDIO FIRE STATION CA US  20150902 -9999 -9999
# GHCND:USC00046635                   PALM SPRINGS CA US  20150902 -9999 -9999
# GHCND:USC00049099               TWENTYNINE PALMS CA US  20150830 -9999 -9999
# GHCND:USC00046168                         NEWMAN CA US  20150731     0     2
# GHCND:USC00049699                    WILLOWS 6 W CA US  20150831     0     2
# GHCND:USC00042012      CORCORAN IRRIGATION DIST. CA US  20150827 -9999 -9999
# GHCND:USC00049785  WOODLAND HILLS PIERCE COLLEGE CA US  20150902 -9999 -9999
# GHCND:USC00049694              WILLOW CREEK 1 NW CA US  20150901   986     7
# ...

# %%
grpA = grp.get_group('GHCND:USC00045502')
grpB = grp.get_group('GHCND:USC00046386')
grpC = grp.get_group('GHCND:USC00040983')

# %%
grpA['Date2']=pd.to_datetime((grpA.DATE).apply(str),'%Y%m%d')
plt.plot(grpA.Date2, grpA.TMIN/10)
plt.plot(grpA.Date2, grpA.TMAX/10)
plt.axis([min(grpA.Date2), max(grpA.Date2), 0, 60])
plt.title('MECCA FIRE STATION CA US')
plt.ylabel('Temperature (C)')
plt.xlabel('Day')
plt.xticks(rotation=90)
plt.show()
# Out:
# /projects/sage/sage-6.9/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
grpB['Date2']=pd.to_datetime((grpB.DATE).apply(str),'%Y%m%d')
plt.plot(grpB.Date2, grpB.TMIN/10)
plt.plot(grpB.Date2, grpB.TMAX/10)
plt.axis([min(grpB.Date2), max(grpB.Date2), 0, 60])
plt.title('OCOTILLO WELLS 2 W CA US')
plt.ylabel('Temperature (C)')
plt.xlabel('Day')
plt.xticks(rotation=90)
plt.show()
# Out:
# /projects/sage/sage-6.9/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
grpC['Date2']=pd.to_datetime((grpC.DATE).apply(str),'%Y%m%d')
plt.plot(grpC.Date2, grpC.TMIN/10)
plt.plot(grpC.Date2, grpC.TMAX/10)
plt.axis([min(grpC.Date2), max(grpC.Date2), 0, 60])
plt.title('BORREGO DESERT PARK CA US')
plt.ylabel('Temperature (C)')
plt.xlabel('Day')
plt.xticks(rotation=90)
plt.show()
# Out:
# /projects/sage/sage-6.9/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# #There was no precipitation for two of the stations and very little for the third.

# %%
df = df[(df.PRCP>0)&(df.DATE>=20150601)&(df.DATE<20150701)]
dat = df[['STATION', 'STATION_NAME', 'PRCP']]
datP = dat[(dat.STATION=='GHCND:USC00045502')|(dat.STATION=='GHCND:USC00046386')|(dat.STATION=='GHCND:USC00040983')]
groupedP = datP.groupby(['STATION', 'STATION_NAME']).aggregate(np.sum)
#groupedP.aggregate(np.sum)
groupedP.plot(kind='bar')
plt.show()

# %%
plt.plot(grpA.DATE, grpA.PRCP/10)
plt.plot(grpA.DATE, grpA.PRCP/10)
plt.axis([20150601, 20150701, 0, 10])
plt.title('MECCA FIRE STATION CA US')
plt.ylabel('Precipitation (mm)')
plt.xlabel('Day')
plt.show()

# %%
plt.plot(grpA.DATE, grpA.PRCP/10)
plt.plot(grpA.DATE, grpA.PRCP/10)
plt.axis([20150101, 20151231, 0, 10])
plt.title('MECCA FIRE STATION CA US')
plt.ylabel('Precipitation (mm)')
plt.xlabel('Day')
plt.show()
